# %% [markdown]
# **Variables**

# %% [markdown]
# Variables are fundamental elements in programming used to store data that can be referenced and manipulated in a program. In Python, variables are created when you assign a value to them,and they do not need explicit declaration to reserve memory space. The declaration happens automatically when you assign a variable

# %% [markdown]
#     . Introduction to Variables
#     . Declaring and assigning variables
#     . Naming conventions
#     . Understanding variable types
#     . Type checking and conversion
#     . Dynamic Typing
#     . Practical examples and common errors

# %%
a = 100

# %%
##declaring and assigfning variables
age = 30
height = 5.7  # in feet
name = "Sanskar"
is_student = True

##prining variables
print("Name : ",name)
print("Age : " , age)
print("Height : " , height)
# Out:
# Name :  Sanskar
# Age :  30
# Height :  5.7

# %%
##Naming conventions
##Variable name should be descriptive
##They must always start with a letter or an underscore '_' and contain letters,numbers and underscores 
##Varible names are case sensitive

##VALID VARIABLE NAMES
first_name = "Sanskar"
last_name = "Dagade"

# %%
##ERRORS
#2age = 30
#first-name = "sanskar"
#@name = "sanskar"

# %%
##Case sensitivity 
name = "sanskar"
Name = "sans"
name == Name
# Out:
# False

# %%
##Understand variable types 
##Python is dynamically typed, type of variable is defined at runtime 

age = 25 #int
height = 6.1 #float
name = "Sansar" #string 
is_student = True #bool

print(type(age))
print(type(is_student))
# Out:
# <class 'int'>
# <class 'bool'>

# %%
##Type checking and conversion
type(height)
# Out:
# float

# %%
age = 25
print(type(age))

##Type conversion

age_str = str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 25
# <class 'str'>

# %%
age = 25
print(type(age))
print(type(str(age)))
print(type(int(age)))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'int'>

# %%
name = "sanskaqr"
print(type(name))
##print(type(int(name))) #ValueError: invalid literal for int() with base 10: 'sanskaqr'
# Out:
# <class 'str'>

# %%
height = 5.1
type(height)
# Out:
# float

# %%
int(height)
# Out:
# 5

# %%
float(int(height))
# Out:
# 5.0

# %%
## Dynamic typing 
## Python allows the type of a variable to change as the program executes

var = 10 #int 
print(var,type(var))

var = "hello"
print(var,type(var))

var = 3.6
print(var,type(var))
# Out:
# 10 <class 'int'>
# hello <class 'str'>
# 3.6 <class 'float'>

# %%
##input
age = input("what is the age")
print(age,type(age))
# Out:
# 12 <class 'str'>

# %%
##input
age = int(input("what is the age"))
print(age,type(age))
# Out:
# 12 <class 'int'>

# %%
##Simple calculator 
num1 = float(input("Enter first numbers: "))
num2 = float(input("Enter first numbers: "))

sums = num1 + num2
difference = num1 - num2
product = num1 * num2
quotient = num1 / num2

print("Sum:" , sums)
print("Difference:" , difference)
print("Multiplication:" , product)
print("Division:" , quotient)
# Out:
# Sum: 7.0
# Difference: 1.0
# Multiplication: 12.0
# Division: 1.3333333333333333
