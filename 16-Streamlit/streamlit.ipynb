# %% [markdown]
# ## Introduction to Streamlit
#
# Streamlit is an open-source app framework for Machine Learning and Data Science Projects. It allows you to create beautiful web applications for machine learning and data science projects with simple pythin scripts.
