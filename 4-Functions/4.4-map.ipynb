# %% [markdown]
# **map()**

# %% [markdown]
# The map() function applies a given function to all items in an input list(or any other iterable ) and returns a map
# object(an iterator). This is particularly useful for transforming data in a list comprehensively.

# %%
def square(x):
    return x * x
square(20)
# Out:
# 400

# %%
numbers = [1,2,3,4,5,67,8,9]
list(map(square,numbers))
# Out:
# [1, 4, 9, 16, 25, 4489, 64, 81]

# %%
##Lambda function with map

numbers = [1,2,3,4,5,6,7,9]
list(map(lambda x:x*x,numbers))
# Out:
# [1, 4, 9, 16, 25, 36, 49, 81]

# %%
##Map multiple iterables

numbers1 = [1,2,3]
numbers2 = [4,5,6]

added_numbers = list(map(lambda x,y:x+y , numbers1,numbers2))
print(added_numbers)
# Out:
# [5, 7, 9]

# %%
##map to convert a list of strings to integers
##use map to convert strings to integers

str_numbers = ['1','2','3','4','5']
int_numbers = list(map(int,str_numbers))
print(int_numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
words = ['apple','banana','cherry']
upper_word = list(map(str.upper,words))
print(upper_word)
# Out:
# ['APPLE', 'BANANA', 'CHERRY']

# %%
def get_name(person):
    return person['name']

people = [
    {'name' : "sanskar", 'age':23},
    {'name' : "sanskarr", 'age':23}
]

list(map(get_name,people))
# Out:
# ['sanskar', 'sanskarr']

# %% [markdown]
# Conclusion:

# %% [markdown]
# The map() function is a powerful tool for applying transformations to iterable data structures. It can be used with regular functions,lambda functions and even multiple iterables,providing a versatule approach to data processing in python. By understanding and utilizing map() you can write more efficient and readable code.
