# %%
import os 
cwd = os.getcwd()
print("Current Working Directory:", cwd)
# Out:
# Current Working Directory: c:\Users\admin\Desktop\PYTHON\6-File Handling

# %%
##create a new directory
new_directory = 'package'
os.mkdir(new_directory)
print(f"Directory '{new_directory}' created successfully.")
# Out:
# Directory 'package' created successfully.

# %%
##Listing files and directories
items = os.listdir('.')
print(items)
# Out:
# ['6.1-fileoperations.ipynb', '6.2-filepath.ipynb', 'destination.txt', 'example.bin', 'example.txt', 'filehandlingquestions.ipynb', 'filehandlingsolution.ipynb', 'package']

# %%
###Joining paths
dir_name = 'folder'
file_name = 'file.txt'
full_path = os.path.join(dir_name, file_name)           ##Getting relative path
print(full_path)
# Out:
# folder\file.txt

# %%
###Joining paths
dir_name = 'folder'
file_name = 'file.txt'
full_path = os.path.join(os.getcwd(),dir_name, file_name)       ##Getting absolute path or full path
print(full_path)
# Out:
# c:\Users\admin\Desktop\PYTHON\6-File Handling\folder\file.txt

# %%
path = 'example1.txt'
if os.path.exists(path):
    print(f"The file '{path}' exists.")
else:
    print(f"The file '{path}' does not exist.")
# Out:
# The file 'example1.txt' does not exist.

# %%
path = 'example1.txt'
if os.path.exists(path):
    print(f"The file '{path}' exists.")
else:
    print(f"The file '{path}' does not exist.")
    ## create the file
    with open(path, 'w') as file:
        file.write("This is an example file.")
        print(f"The file '{path}' has been created.")
# Out:
# The file 'example1.txt' does not exist.
# The file 'example1.txt' has been created.

# %%
##Checking if the path is a file or directory
path = 'example1.txt'
if os.path.isfile(path):
    print(f"'{path}' is a file.")
elif os.path.isdir(path):
    print(f"'{path}' is a directory.")
else:
    print(f"The path '{path}' is not a valid file or directory.")
# Out:
# 'example1.txt' is a file.

# %%
##Getting the absolute path of a file
relative_path = 'example1.txt'
absolute_path = os.path.abspath(relative_path)
print(f"Absolute path of '{relative_path}': {absolute_path}")
# Out:
# Absolute path of 'example1.txt': c:\Users\admin\Desktop\PYTHON\6-File Handling\example1.txt
